# %%
import os
import torch
from AssistiveOptimization import AssistiveTexturization, run_texturization
import warnings
warnings.filterwarnings("ignore")

# %%
settings = {
    'out_path': 'outputs',
    'n_views': 5,
    'n_iter': 40,
    'lr': 5e-2,
    'tv_loss':1e-6,
    'image_size': 512,
    'device': torch.device('cuda' if torch.cuda.is_available() else 'cpu'),
    'meshes': { 
        'jeep':{
           'init_color': [128.,128.,128.], # Initial RGB color
            'inter_cam': [2.0, 10, 15, 0, 260],
            'target': 609, # ImageNet Label
        },
        'lexus':{
           'init_color': [128.,128.,128.], # Initial RGB color
            'inter_cam': [2.0, -80, -20, 0, 0],
            'target': 717, # ImageNet Label
        }
    },
    # Test models
    'model_names': ['resnet','squeezenet']
}

# Run Texturization
run_texturization(settings)
# Out:
# **************************************************
# jeep - resnet
# **************************************************
# Loading models...
#   0%|          | 0/40 [00:00<?, ?it/s]
# Prediction Baseline
# Prediction Image_0_Pred:609, Score: 0.16859089
# Prediction Image_1_Pred:717, Score: 0.59270054
# Prediction Image_2_Pred:717, Score: 0.45976588
# Prediction Image_3_Pred:482, Score: 0.17089637
# Prediction Image_4_Pred:436, Score: 0.37513444
# Prediction Full Assistive Texture - Robust Design
# Prediction Image_0_Pred:609, Score: 0.99470216
# Prediction Image_1_Pred:609, Score: 0.99409676
# Prediction Image_2_Pred:609, Score: 0.9959513
# Prediction Image_3_Pred:609, Score: 0.9959008
# Prediction Image_4_Pred:609, Score: 0.99633443
# **************************************************
# jeep - squeezenet
# **************************************************
# Loading models...
#   0%|          | 0/40 [00:00<?, ?it/s]
# Prediction Baseline
# Prediction Image_0_Pred:759, Score: 0.113145605
# Prediction Image_1_Pred:895, Score: 0.7977185
# Prediction Image_2_Pred:895, Score: 0.70830387
# Prediction Image_3_Pred:759, Score: 0.42044023
# Prediction Image_4_Pred:895, Score: 0.9321058
# Prediction Full Assistive Texture - Robust Design
# Prediction Image_0_Pred:609, Score: 0.9891481
# Prediction Image_1_Pred:609, Score: 0.9844855
# Prediction Image_2_Pred:609, Score: 0.99128646
# Prediction Image_3_Pred:609, Score: 0.9902423
# Prediction Image_4_Pred:609, Score: 0.99127215
# **************************************************
# lexus - resnet
# **************************************************
# Loading models...
#   0%|          | 0/40 [00:00<?, ?it/s]
# Prediction Baseline
# Prediction Image_0_Pred:436, Score: 0.28924745
# Prediction Image_1_Pred:511, Score: 0.5464808
# Prediction Image_2_Pred:479, Score: 0.20886827
# Prediction Image_3_Pred:408, Score: 0.13784458
# Prediction Image_4_Pred:851, Score: 0.3992648
# Prediction Full Assistive Texture - Robust Design
# Prediction Image_0_Pred:717, Score: 0.93256056
# Prediction Image_1_Pred:717, Score: 0.88695693
# Prediction Image_2_Pred:717, Score: 0.8796301
# Prediction Image_3_Pred:717, Score: 0.87454534
# Prediction Image_4_Pred:717, Score: 0.7867365
# **************************************************
# lexus - squeezenet
# **************************************************
# Loading models...
#   0%|          | 0/40 [00:00<?, ?it/s]
# Prediction Baseline
# Prediction Image_0_Pred:586, Score: 0.58861864
# Prediction Image_1_Pred:447, Score: 0.28134754
# Prediction Image_2_Pred:895, Score: 0.14401083
# Prediction Image_3_Pred:895, Score: 0.35482636
# Prediction Image_4_Pred:632, Score: 0.31580612
# Prediction Full Assistive Texture - Robust Design
# Prediction Image_0_Pred:717, Score: 0.71687233
# Prediction Image_1_Pred:717, Score: 0.7408396
# Prediction Image_2_Pred:717, Score: 0.7892021
# Prediction Image_3_Pred:717, Score: 0.8930959
# Prediction Image_4_Pred:717, Score: 0.8835459
